# %%
from infer_veritas import  *
from truthfinder import *

# %%
# %%time
TR=truthnet(datapath='/home/ishanu/ZED/Research/truthnet/notebooks/data/ptsd/PTSD_cognet_test.csv',target_label='PTSDDx',query_limit=20)
TR.fit(shapnum=10)
rf=TR.calibrate(calibration_num=10000)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████| 10000/10000 [25:52<00:00,  6.44it/s]
# ckeck passed
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [lognorm] [0.15 sec] [RSS: 0.792919] [loc=0.202 scale=0.817]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [smoothline] >Smoothing by interpolation..
# [distfit] >INFO> [lognorm] [0.27 sec] [RSS: 20.0834] [loc=0.176 scale=0.467]
# [distfit] >INFO> Compute confidence intervals [parametric]
# ckeck passed
# CPU times: user 1h 58min 30s, sys: 1min 25s, total: 1h 59min 55s
# Wall time: 1h 58min 24s

# %%
TR.veritas_model
# Out:
# {'version': '0.0.1',
#  'model': qnet.Qnet,
#  'model_neg': qnet.Qnet,
#  'problem': '',
#  'dist_lower': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x7f270102a620>,
#  'LOWER_THRESHOLD': 0.8844413579814692,
#  'dist_veritas': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x7f26ffd6cbe0>,
#  'VERITAS_THRESHOLD': 0.7449172965651525,
#  'upper_scoretoprobability': <bound method processRoc.scoretoprobability of <zedstat.zedstat.processRoc object at 0x7f2702ebe500>>,
#  'UPPER_THRESHOLD': 1.3335246857466934,
#  'AUC': (0.827016393442623, 0.8340138650188591, 0.8200189218663867)}

# %%
TR.veritas_model
# Out:
# {'version': '0.0.1',
#  'model': qnet.Qnet,
#  'model_neg': qnet.Qnet,
#  'problem': '',
#  'dist_lower': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x7f270102a620>,
#  'LOWER_THRESHOLD': 0.8844413579814692,
#  'dist_veritas': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x7f26ffd6cbe0>,
#  'VERITAS_THRESHOLD': 0.7449172965651525,
#  'upper_scoretoprobability': <bound method processRoc.scoretoprobability of <zedstat.zedstat.processRoc object at 0x7f2702ebe500>>,
#  'UPPER_THRESHOLD': 1.3335246857466934,
#  'AUC': (0.827016393442623, 0.8340138650188591, 0.8200189218663867)}

# %%
rf[1]
# Out:
#       veritas     upper     lower
# 0    0.700000  1.019543  1.197358
# 1    0.880000  1.106177  1.109352
# 2    0.912879  0.570235  1.769176
# 3    0.648402  1.338771  0.942512
# 4    0.921538  0.906826  1.235621
# ..        ...       ...       ...
# 208  0.918333  0.770930  1.545655
# 209  0.600000  1.204298  0.945289
# 210  0.732785  0.809398  1.267176
# 211  0.712785  1.033738  1.165056
# 212  0.860000  0.755273  1.397144
#
# [213 rows x 3 columns]

# %%
from distfit import distfit  # Distribution fitting
from scipy.stats import t,lognorm  # Used for statistical functions
from zedstat import zedstat  # Custom statistical package

# %%
a=rf[0].lower.values
a.sort()
import pylab as plt
plt.plot(a)

# %%
rf[0].lower.mean()
# Out:
# 1.0267831695340766

# %%
dfit = distfit()
dfit.fit_transform(rf[0].lower.values)
dfit.plot()
#df, loc, scale = dfit.model['params']
#dist = t(df, loc=loc, scale=scale)
#dist.ppf(TR.threshold_alpha)
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 2.36992] [loc=1.027 scale=0.116]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 114.833] [loc=0.672 scale=0.355]
# [distfit] >INFO> [pareto    ] [0.01 sec] [RSS: 114.833] [loc=-33554431.328 scale=33554432.000]
# [distfit] >INFO> [dweibull  ] [0.07 sec] [RSS: 3.2949] [loc=1.025 scale=0.100]
# [distfit] >INFO> [t         ] [0.52 sec] [RSS: 2.36138] [loc=1.026 scale=0.113]
# [distfit] >INFO> [genextreme] [0.34 sec] [RSS: 0.75104] [loc=0.979 scale=0.107]
# [distfit] >INFO> [gamma     ] [0.03 sec] [RSS: 0.758544] [loc=0.466 scale=0.024]
# [distfit] >INFO> [lognorm   ] [0.15 sec] [RSS: 0.792919] [loc=0.202 scale=0.817]
# [distfit] >INFO> [beta      ] [0.22 sec] [RSS: 0.741509] [loc=0.517 scale=5.124]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 96.58] [loc=0.672 scale=0.954]
# [distfit] >INFO> [loggamma  ] [0.14 sec] [RSS: 2.54872] [loc=-27.177 scale=4.005]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [distfit] >INFO> Create pdf plot for the parametric method.
# [distfit] >INFO> Estimated distribution: Beta(loc:0.516848, scale:5.124461)
# (<Figure size 1440x1080 with 1 Axes>,
#  <AxesSubplot:title={'center':'\nbeta(a=17.28, b=156.371, loc=0.516848, scale=5.12446)'}, xlabel='Values', ylabel='Frequency'>)

# %%
dfit.plot()
# Out:
# [distfit] >INFO> Create pdf plot for the parametric method.
# [distfit] >INFO> Estimated distribution: Beta(loc:0.516848, scale:5.124461)
# (<Figure size 1440x1080 with 1 Axes>,
#  <AxesSubplot:title={'center':'\nbeta(a=17.28, b=156.371, loc=0.516848, scale=5.12446)'}, xlabel='Values', ylabel='Frequency'>)
