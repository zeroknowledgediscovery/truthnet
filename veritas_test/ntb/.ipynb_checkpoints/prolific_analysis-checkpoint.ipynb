# %%
import pandas as pd
import glob
import json

def getEXPTRES(dirpath):
    # Create an empty list to store the data.
    data = []

    # Loop through each file in the directory matching the JSON file extension.
    for file in glob.glob(dirpath):
        with open(file, 'r') as f:
            # Load the content of the file as JSON.
            content = json.load(f)
            # Loop through each record in the JSON file.
            for record in content:
                # Extract the desired fields and add them to the data list.
                data.append({
                    'subject_id': record.get('subject_id', None),
                    'score': record.get('score', None),
                    'veritas': record.get('veritas', None),
                    'lower_threshold': record.get('lower_threshold', None),
                    'veritas_prob': record.get('veritas_prob', None)
                })

    # Create a DataFrame from the collected data.
    return pd.DataFrame(data).set_index('subject_id')

def getEXPTRES_(dirpath,ids):
    # Create an empty list to store the data.
    data = []

    # Loop through each file in the directory matching the JSON file extension.
    for file in glob.glob(dirpath):
        with open(file, 'r') as f:
            # Load the content of the file as JSON.
            content = json.load(f)
            # Loop through each record in the JSON file.
            for record in content:
                # Extract the desired fields and add them to the data list.
                if record.get('subject_id', None) in ids:
                    data.append({
                        'subject_id': record.get('subject_id', None),
                        'responses': record.get('responses', None),
                        'score': record.get('score', None),
                        'veritas': record.get('veritas', None),
                        'lower_threshold': record.get('lower_threshold', None),
                        'veritas_prob': record.get('veritas_prob', None)
                    })
                
                    

    # Create a DataFrame from the collected data.
    return pd.DataFrame(data).set_index('subject_id')

# %%
dirpath='../veritas-experiment/*json'

# %%
df=getEXPTRES(dirpath)

# %%
df
# Out:
#                                 score   veritas  lower_threshold  veritas_prob
# subject_id
# prolificuserkkoamwaa8x       2.086982  0.766667         0.740192      0.975565
# prolificuserjdxu06o70li_UK   1.175450  0.733333         1.147581      0.925737
# prolificuseruu9wkw1ue2       2.361640  0.733333         0.786850      0.925737
# prolificuserekzewvrhyfn_UK   1.957559  0.700000         0.936673      0.757700
# prolificuserznbqrjgxnyd      0.653970  0.857143         1.453932      0.997380
# ...                               ...       ...              ...           ...
# prolificusermyugdsqgbq       0.856659  0.766667         0.933389      0.975565
# prolificuservfpw5mtor4f_UK   2.106645  0.716667         0.698563      0.864912
# prolificuser8dt970xc68b      1.757962  0.700588         0.965689      0.762442
# prolificuser3x4z37pqe5a      2.137452  0.714286         0.703487      0.852854
# prolificuser086kmobbvv2n_UK  1.395745  0.800000         0.742677      0.990501
#
# [231 rows x 4 columns]

# %%
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style()
sns.distplot(df.veritas)
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='veritas', ylabel='Density'>

# %%
sns.distplot(df.lower_threshold)
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lower_threshold', ylabel='Density'>

# %%
sns.distplot(df.score)
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='score', ylabel='Density'>

# %%
ax=sns.scatterplot(data=df,x='score',y='veritas',size='lower_threshold')
ax.plot([1.35,1.35],[0.55,1],'-r')
ax.plot([.5,3],[0.76,.76],'-r')

# %%
def malingerFlag(row):
    C0=.99999
    C1=.759
    C2=1.35
    if (row.veritas > C1) and (row.score > C2):
        return 0
    if (row.lower_threshold < C0) and (row.score > C2):
        return 0    
    if (row.score > C2):
        return 1
    return -1

# %%
df['mg']=df.apply(malingerFlag,axis=1)
df[df.mg==1].index.size/df.index.size
# Out:
# 0.06060606060606061

# %%
df.index.size-df[df.mg==1].index.size
# Out:
# 217

# %%
df_US = df[~df.index.str.endswith('_US')]

# %%
df_UK = df[~df.index.str.endswith('_UK')]

# %%
df.mg.value_counts()
# Out:
#  0    135
# -1     60
#  1     36
# Name: mg, dtype: int64

# %%
df[df.mg==1].index.size
# Out:
# 14

# %%
ratio = df[df.mg==1].index.size/df.index.size
ratio
# Out:
# 0.06060606060606061

# %%
ratio = df_UK[df_UK.mg==1].index.size/df_UK.index.size
ratio
# Out:
# 0.14166666666666666

# %%
ratio = df_US[df_US.mg==1].index.size/df_US.index.size
ratio
# Out:
# 0.15584415584415584

# %%
sns.jointplot(data=df_UK,x='lower_threshold',y='veritas',kind='kde')
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/seaborn/_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1606179/51152220.py in <module>
# ----> 1 sns.jointplot(data=df_UK,x='lower_threshold',y='veritas',kind='kde')
#
# ~/.local/lib/python3.10/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.10/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2282         joint_kws.setdefault("color", color)
#    2283         joint_kws.setdefault("warn_singular", False)
# -> 2284         grid.plot_joint(kdeplot, **joint_kws)
#    2285
#    2286         marginal_kws.setdefault("color", color)
#
# ~/.local/lib/python3.10/site-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1804
#    1805         if str(func.__module__).startswith("seaborn"):
# -> 1806             func(x=self.x, y=self.y, **kwargs)
#    1807         else:
#    1808             func(self.x, self.y, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.10/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1781     else:
#    1782
# -> 1783         p.plot_bivariate_density(
#    1784             common_norm=common_norm,
#    1785             fill=fill,
#
# ~/.local/lib/python3.10/site-packages/seaborn/distributions.py in plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1084         densities, supports = {}, {}
#    1085
# -> 1086         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#    1087
#    1088             # Extract the data points from this sub set and remove nulls
#
# ~/.local/lib/python3.10/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/.local/lib/python3.10/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1688             self._setitem_with_indexer_split_path(indexer, value, name)
#    1689         else:
# -> 1690             self._setitem_single_block(indexer, value, name)
#    1691
#    1692     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1927             # setting for extensionarrays that store dicts. Need to decide
#    1928             # if it's worth supporting that.
# -> 1929             value = self._align_series(indexer, Series(value))
#    1930
#    1931         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2089                 if obj.ndim == 2 and is_empty_indexer(indexer[0], ser._values):
#    2090                     return ser._values.copy()
# -> 2091                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2092
#    2093                 # single indexer
#
# ~/.local/lib/python3.10/site-packages/pandas/core/series.py in reindex(self, *args, **kwargs)
#    4670                 )
#    4671             kwargs.update({"index": index})
# -> 4672         return super().reindex(**kwargs)
#    4673
#    4674     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4964
#    4965         # perform the reindex on the axes
# -> 4966         return self._reindex_axes(
#    4967             axes, level, limit, tolerance, method, fill_value, copy
#    4968         ).__finalize__(self, method="reindex")
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4984
#    4985             axis = self._get_axis_number(a)
# -> 4986             obj = obj._reindex_with_indexers(
#    4987                 {axis: [new_index, indexer]},
#    4988                 fill_value=fill_value,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5030
#    5031             # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032             new_data = new_data.reindex_indexer(
#    5033                 index,
#    5034                 indexer,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677         # some axes don't allow reindexing with dups
#     678         if not allow_dups:
# --> 679             self.axes[axis]._validate_can_reindex(indexer)
#     680
#     681         if axis >= self.ndim:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    4105         # trying to reindex on an axis with duplicates
#    4106         if not self._index_as_unique and len(indexer):
# -> 4107             raise ValueError("cannot reindex on an axis with duplicate labels")
#    4108
#    4109     def reindex(
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
df[df.mg==1].index.size
# Out:
# 14

# %%
mf=df[df.mg==1]

# %%
mf_=getEXPTRES_(dirpath,mf.index.values.astype(str))

# %%
sns.distplot(mf_.veritas_prob)
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='veritas_prob', ylabel='Density'>

# %%
mf_.loc['prolificusermhp0mw0er3m']
# Out:
# responses          {'ptsd179': '4', 'ptsd40': '4', 'ptsd31': '5',...
# score                                                       1.646387
# veritas                                                     0.666667
# lower_threshold                                             1.115846
# veritas_prob                                                0.406923
# Name: prolificusermhp0mw0er3m, dtype: object

# %%
af=getEXPTRES_(dirpath,df.index.values.astype(str))

# %%
def getJson(row):
    return {row.name:row.responses}

# %%
eson=list(af.apply(getJson,axis=1).values)

# %%
import sys
sys.path.append("/home/ishanu/ZED/Research/truthnet/veritas_test/") 
from infer_veritas import  *
from truthfinder import *
import gzip
import seaborn as sns

# %%
rff2=reveal(eson,"/home/ishanu/ZED/Research/truthnet/veritas_test/veritas_models/veritas_004.pkl.gz")
# Out:
# ckeck passed

# %%
RFF2=pd.DataFrame([(x['subject_id'],x['lower_threshold'],x['veritas'],x['score']) for x in rff2[0]],
                 columns=['sub','lower_threshold','veritas','score']).set_index('sub')

# %%
sns.scatterplot(data=RFF2,x='score',y='veritas',hue='lower_threshold')
# Out:
# <AxesSubplot:xlabel='score', ylabel='veritas'>

# %%
sns.distplot(RFF2.lower_threshold)
# Out:
# <AxesSubplot:xlabel='lower_threshold', ylabel='Density'>

# %%
RFF2['mg']=RFF2.apply(malingerFlag,axis=1)
RFF2[RFF2.mg==1].index.size/RFF2.index.size
# Out:
# 0.06493506493506493

# %%
4/0.05194805194805195
# Out:
# 77.0

# %%
RFF=pd.DataFrame([(x['subject_id'],x['lower_threshold'],x['veritas'],x['score']) for x in rff[0]],
                 columns=['sub','lower_threshold','veritas','score']).set_index('sub')

# %%
sns.scatterplot(data=RFF,x='score',y='veritas',hue='lower_threshold')
# Out:
# <AxesSubplot:xlabel='score', ylabel='veritas'>

# %%
sns.distplot(RFF.lower_threshold)
# Out:
# <AxesSubplot:xlabel='lower_threshold', ylabel='Density'>

# %%
sns.distplot(RFF.veritas)
# Out:
# <AxesSubplot:xlabel='veritas', ylabel='Density'>

# %%
RFF['mg']=RFF.apply(malingerFlag,axis=1)
RFF[RFF.mg==1].index.size/RFF.index.size
# Out:
# 0.05194805194805195

# %%
RFF[RFF.mg==1]
# Out:
#                                         lower_threshold   veritas     score  \
# sub
# prolificuser9fnptex4yrc                        1.199871  0.750903  1.582172
# prolificuserf0wffkpm2ih_UK                     1.023625  0.714286  1.794843
# 60c71db92651d246c6081107ejnsl7lx1gq_UK         1.044423  0.733333  1.413876
# prolificuserwfma5boo7b_UK                      1.070137  0.715000  1.672725
# prolificuserxargfwk4z4r                        1.100236  0.720000  1.815906
# prolificuserns5m31kjzwg_UK                     1.087592  0.720000  1.905634
# prolificuser5w3s4ia44b_UK                      1.088059  0.720000  1.418645
# prolificuser7ajigtllpml                        1.011328  0.680000  1.846352
# prolificusergwybcn66hqc_UK                     1.030469  0.666667  1.955821
# prolificuser9vrm7z6kcq5_UK                     1.026306  0.710306  1.405401
# prolificuserfv1luscxtv_UK                      1.026470  0.740000  1.843927
# prolificusermyugdsqgbq                         1.100218  0.727273  1.805196
#
#                                         mg
# sub
# prolificuser9fnptex4yrc                  1
# prolificuserf0wffkpm2ih_UK               1
# 60c71db92651d246c6081107ejnsl7lx1gq_UK   1
# prolificuserwfma5boo7b_UK                1
# prolificuserxargfwk4z4r                  1
# prolificuserns5m31kjzwg_UK               1
# prolificuser5w3s4ia44b_UK                1
# prolificuser7ajigtllpml                  1
# prolificusergwybcn66hqc_UK               1
# prolificuser9vrm7z6kcq5_UK               1
# prolificuserfv1luscxtv_UK                1
# prolificusermyugdsqgbq                   1
