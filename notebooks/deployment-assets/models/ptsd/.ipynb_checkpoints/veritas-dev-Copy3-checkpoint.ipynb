# %%
from quasinet.qnet import load_qnet
from quasinet.qnet import qdistance
from quasinet.qsampling import qsample
from quasinet.qnet import membership_degree
import pandas as pd
import numpy as np
from tqdm import tqdm
from jupyterthemes import jtplot
jtplot.style()

# %%
def dissonance(pos,seq,model):
    if seq[pos]=='':
        return np.nan
    D=model.predict_distributions(seq) 
    return 1-D[pos].get(str(seq[pos]),0)

def dissonance_distr(seq,model):
    return np.array([dissonance(pos,seq,model) for pos in range(len(seq))])

def dissonance_distr_median(seq,model):
    a=dissonance_distr(seq,model)
    return np.median(a[~np.isnan(a)])


# Function to read the JSON file and extract the top-level keys as subject ID and the associated dictionary as responses
def extract_ptsd_items(jsondata):
        data=jsondata
        subjects = []
        for entry in data:
            for subject_id, responses in entry.items():
                subjects.append({"subject_id": subject_id,
                                 "responses": responses})
        return subjects

import random
def funcw(s,model_pos,model_neg,
          dropone=False,
          perturb=False,
          perturbsteps=100):
    if dropone:
        s[random.randint(0, len(s) - 1)] = str(random.randint(1,5))
    if perturb:
        s=qsample(s,model_neg,steps=perturbsteps)
    return membership_degree(s,model_neg)/membership_degree(s,model_pos)

    
def reveal(jsondata,veritas_model,modelneg=False):
    list_response_dict = extract_ptsd_items(jsondata)
    for i in list_response_dict:
        subjectid=i['subject_id']
        resp = i['responses']
        s=pd.concat([pd.DataFrame(columns=veritas_model['model'].feature_names),
                   pd.DataFrame(resp,index=['response'])])\
                        .fillna('').values[0].astype(str)
        i['veritas']=dissonance_distr_median(s,veritas_model['model'])
        i['veritas_prob']=veritas_model['t_distribution'].cdf(i['veritas'])
        if modelneg:
            i['score']=funcw(s,
                             veritas_model['model'],
                             veritas_model['model_neg'])
    return list_response_dict


def classscore(jsondata,model,modelneg):
    list_response_dict = extract_ptsd_items(jsondata)
    for i in list_response_dict:
        subjectid=i['subject_id']
        resp = i['responses']
        s=pd.concat([pd.DataFrame(columns=model.feature_names),
                   pd.DataFrame(resp,index=['response'])])\
                        .fillna('').values[0].astype(str)
        i['funcw']=funcw(s,model,modelneg)
    return list_response_dict

# %%
import gzip
import dill
vmodelpath='veritas_ptsd.pkl.gz'
with gzip.open(vmodelpath, 'rb') as f:
    veritas_ptsd = dill.load(f)

# %%
import json
filepath='/home/ishanu/Dropbox/paraknowledge/paraknowledgecorp/saas/cloud_functions/test_deployments/ptsd.json'
with open(filepath, 'r') as file:
    data = json.load(file)
R=reveal(data,veritas_ptsd,modelneg=True)
R
# Out:
# [{'subject_id': '35',
#   'responses': {'ptsd1': 1,
#    'ptsd2': 1,
#    'ptsd3': 1,
#    'ptsd4': 1,
#    'ptsd5': 1,
#    'ptsd6': 1,
#    'ptsd7': 1,
#    'ptsd8': 1,
#    'ptsd9': 1,
#    'ptsd10': 2,
#    'ptsd11': 1,
#    'ptsd12': 1,
#    'ptsd13': 1,
#    'ptsd14': 1,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 1,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 1,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 1,
#    'ptsd33': 1,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 1,
#    'ptsd37': 1,
#    'ptsd38': 1,
#    'ptsd39': 1,
#    'ptsd40': 1,
#    'ptsd41': 1,
#    'ptsd42': 1,
#    'ptsd43': 5,
#    'ptsd44': 1,
#    'ptsd45': 4,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 1,
#    'ptsd49': 1,
#    'ptsd50': 1,
#    'ptsd51': 1,
#    'ptsd52': 1,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 1,
#    'ptsd57': 1,
#    'ptsd58': 1,
#    'ptsd59': 1,
#    'ptsd60': 1,
#    'ptsd61': 1,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 1,
#    'ptsd66': 1,
#    'ptsd67': 1,
#    'ptsd68': 1,
#    'ptsd69': 1,
#    'ptsd70': 1,
#    'ptsd71': 1,
#    'ptsd72': 1,
#    'ptsd73': 1,
#    'ptsd74': 1,
#    'ptsd75': 1,
#    'ptsd76': 1,
#    'ptsd77': 1,
#    'ptsd78': 1,
#    'ptsd79': 1,
#    'ptsd80': 1,
#    'ptsd81': 1,
#    'ptsd82': 1,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 1,
#    'ptsd86': 1,
#    'ptsd87': 1,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 1,
#    'ptsd91': 1,
#    'ptsd92': 1,
#    'ptsd93': 1,
#    'ptsd94': 1,
#    'ptsd95': 1,
#    'ptsd96': 1,
#    'ptsd97': 1,
#    'ptsd98': 1,
#    'ptsd99': 1,
#    'ptsd100': 1,
#    'ptsd101': 1,
#    'ptsd102': 1,
#    'ptsd103': 1,
#    'ptsd104': 1,
#    'ptsd105': 1,
#    'ptsd106': 1,
#    'ptsd107': 1,
#    'ptsd108': 1,
#    'ptsd109': 1,
#    'ptsd110': 1,
#    'ptsd111': 1,
#    'ptsd112': 1,
#    'ptsd113': 4,
#    'ptsd114': 1,
#    'ptsd115': 4,
#    'ptsd116': 5,
#    'ptsd117': 1,
#    'ptsd118': 1,
#    'ptsd119': 1,
#    'ptsd120': 1,
#    'ptsd121': 1,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 1,
#    'ptsd125': 1,
#    'ptsd126': 1,
#    'ptsd127': 1,
#    'ptsd128': 1,
#    'ptsd129': 1,
#    'ptsd130': 1,
#    'ptsd131': 1,
#    'ptsd132': 1,
#    'ptsd133': 1,
#    'ptsd134': 1,
#    'ptsd135': 1,
#    'ptsd136': 1,
#    'ptsd137': 1,
#    'ptsd138': 1,
#    'ptsd139': 1,
#    'ptsd140': 1,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 1,
#    'ptsd144': 1,
#    'ptsd145': 1,
#    'ptsd146': 1,
#    'ptsd147': 1,
#    'ptsd148': 1,
#    'ptsd149': 1,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 1,
#    'ptsd154': 1,
#    'ptsd155': 1,
#    'ptsd156': 1,
#    'ptsd157': 1,
#    'ptsd158': 1,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 1,
#    'ptsd165': 1,
#    'ptsd166': 1,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 1,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 1,
#    'ptsd175': 1,
#    'ptsd176': 1,
#    'ptsd177': 1,
#    'ptsd178': 1,
#    'ptsd179': 1,
#    'ptsd180': 1,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 1,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 1,
#    'ptsd198': 1,
#    'ptsd199': 1,
#    'ptsd200': 1,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 1,
#    'ptsd204': 1,
#    'ptsd205': 1,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 1,
#    'ptsd209': 1,
#    'ptsd210': 1,
#    'ptsd211': 1},
#   'veritas': 0.9206349206349206,
#   'veritas_prob': 0.9991221435882433,
#   'score': 0.31158984832112646},
#  {'subject_id': '59',
#   'responses': {'ptsd1': 1,
#    'ptsd2': 1,
#    'ptsd3': 1,
#    'ptsd4': 2,
#    'ptsd5': 1,
#    'ptsd6': 1,
#    'ptsd7': 1,
#    'ptsd8': 1,
#    'ptsd9': 1,
#    'ptsd10': 1,
#    'ptsd11': 1,
#    'ptsd12': 1,
#    'ptsd13': 1,
#    'ptsd14': 1,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 1,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 1,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 1,
#    'ptsd33': 1,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 1,
#    'ptsd37': 1,
#    'ptsd38': 1,
#    'ptsd39': 1,
#    'ptsd40': 2,
#    'ptsd41': 1,
#    'ptsd42': 1,
#    'ptsd43': 5,
#    'ptsd44': 1,
#    'ptsd45': 5,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 1,
#    'ptsd49': 1,
#    'ptsd50': 1,
#    'ptsd51': 1,
#    'ptsd52': 1,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 1,
#    'ptsd57': 1,
#    'ptsd58': 1,
#    'ptsd59': 1,
#    'ptsd60': 1,
#    'ptsd61': 3,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 1,
#    'ptsd66': 1,
#    'ptsd67': 1,
#    'ptsd68': 1,
#    'ptsd69': 1,
#    'ptsd70': 1,
#    'ptsd71': 1,
#    'ptsd72': 1,
#    'ptsd73': 1,
#    'ptsd74': 1,
#    'ptsd75': 1,
#    'ptsd76': 1,
#    'ptsd77': 1,
#    'ptsd78': 1,
#    'ptsd79': 1,
#    'ptsd80': 1,
#    'ptsd81': 1,
#    'ptsd82': 1,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 1,
#    'ptsd86': 1,
#    'ptsd87': 1,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 1,
#    'ptsd91': 1,
#    'ptsd92': 1,
#    'ptsd93': 1,
#    'ptsd94': 3,
#    'ptsd95': 1,
#    'ptsd96': 1,
#    'ptsd97': 1,
#    'ptsd98': 1,
#    'ptsd99': 1,
#    'ptsd100': 1,
#    'ptsd101': 1,
#    'ptsd102': 1,
#    'ptsd103': 1,
#    'ptsd104': 2,
#    'ptsd105': 1,
#    'ptsd106': 1,
#    'ptsd107': 1,
#    'ptsd108': 1,
#    'ptsd109': 3,
#    'ptsd110': 1,
#    'ptsd111': 1,
#    'ptsd112': 1,
#    'ptsd113': 5,
#    'ptsd114': 1,
#    'ptsd115': 1,
#    'ptsd116': 4,
#    'ptsd117': 4,
#    'ptsd118': 1,
#    'ptsd119': 1,
#    'ptsd120': 1,
#    'ptsd121': 1,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 1,
#    'ptsd125': 1,
#    'ptsd126': 1,
#    'ptsd127': 1,
#    'ptsd128': 1,
#    'ptsd129': 1,
#    'ptsd130': 1,
#    'ptsd131': 1,
#    'ptsd132': 1,
#    'ptsd133': 1,
#    'ptsd134': 1,
#    'ptsd135': 1,
#    'ptsd136': 1,
#    'ptsd137': 1,
#    'ptsd138': 1,
#    'ptsd139': 1,
#    'ptsd140': 1,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 1,
#    'ptsd144': 1,
#    'ptsd145': 1,
#    'ptsd146': 1,
#    'ptsd147': 1,
#    'ptsd148': 1,
#    'ptsd149': 1,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 1,
#    'ptsd154': 1,
#    'ptsd155': 1,
#    'ptsd156': 1,
#    'ptsd157': 1,
#    'ptsd158': 1,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 1,
#    'ptsd165': 1,
#    'ptsd166': 1,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 1,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 1,
#    'ptsd175': 1,
#    'ptsd176': 1,
#    'ptsd177': 1,
#    'ptsd178': 1,
#    'ptsd179': 1,
#    'ptsd180': 1,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 1,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 1,
#    'ptsd198': 1,
#    'ptsd199': 1,
#    'ptsd200': 1,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 1,
#    'ptsd204': 1,
#    'ptsd205': 1,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 1,
#    'ptsd209': 1,
#    'ptsd210': 1,
#    'ptsd211': 2},
#   'veritas': 0.9133858267716535,
#   'veritas_prob': 0.9990185824619143,
#   'score': 0.3057445486056005},
#  {'subject_id': '193',
#   'responses': {'ptsd1': 5,
#    'ptsd2': 2,
#    'ptsd3': 2,
#    'ptsd4': 3,
#    'ptsd5': 1,
#    'ptsd6': 1,
#    'ptsd7': 1,
#    'ptsd8': 1,
#    'ptsd9': 1,
#    'ptsd10': 3,
#    'ptsd11': 1,
#    'ptsd12': 1,
#    'ptsd13': 1,
#    'ptsd14': 1,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 1,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 1,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 1,
#    'ptsd33': 1,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 1,
#    'ptsd37': 1,
#    'ptsd38': 1,
#    'ptsd39': 1,
#    'ptsd40': 1,
#    'ptsd41': 1,
#    'ptsd42': 1,
#    'ptsd43': 1,
#    'ptsd44': 2,
#    'ptsd45': 5,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 1,
#    'ptsd49': 1,
#    'ptsd50': 1,
#    'ptsd51': 1,
#    'ptsd52': 1,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 2,
#    'ptsd56': 1,
#    'ptsd57': 1,
#    'ptsd58': 2,
#    'ptsd59': 2,
#    'ptsd60': 1,
#    'ptsd61': 2,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 2,
#    'ptsd66': 1,
#    'ptsd67': 1,
#    'ptsd68': 1,
#    'ptsd69': 2,
#    'ptsd70': 2,
#    'ptsd71': 2,
#    'ptsd72': 1,
#    'ptsd73': 1,
#    'ptsd74': 1,
#    'ptsd75': 1,
#    'ptsd76': 1,
#    'ptsd77': 1,
#    'ptsd78': 1,
#    'ptsd79': 1,
#    'ptsd80': 2,
#    'ptsd81': 1,
#    'ptsd82': 1,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 1,
#    'ptsd86': 2,
#    'ptsd87': 1,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 1,
#    'ptsd91': 2,
#    'ptsd92': 1,
#    'ptsd93': 1,
#    'ptsd94': 2,
#    'ptsd95': 1,
#    'ptsd96': 2,
#    'ptsd97': 2,
#    'ptsd98': 1,
#    'ptsd99': 1,
#    'ptsd100': 1,
#    'ptsd101': 2,
#    'ptsd102': 2,
#    'ptsd103': 1,
#    'ptsd104': 1,
#    'ptsd105': 1,
#    'ptsd106': 2,
#    'ptsd107': 2,
#    'ptsd108': 1,
#    'ptsd109': 2,
#    'ptsd110': 1,
#    'ptsd111': 2,
#    'ptsd112': 1,
#    'ptsd113': 5,
#    'ptsd114': 1,
#    'ptsd115': 3,
#    'ptsd116': 3,
#    'ptsd117': 1,
#    'ptsd118': 1,
#    'ptsd119': 1,
#    'ptsd120': 2,
#    'ptsd121': 1,
#    'ptsd122': 1,
#    'ptsd123': 2,
#    'ptsd124': 1,
#    'ptsd125': 1,
#    'ptsd126': 1,
#    'ptsd127': 1,
#    'ptsd128': 1,
#    'ptsd129': 1,
#    'ptsd130': 1,
#    'ptsd131': 1,
#    'ptsd132': 1,
#    'ptsd133': 1,
#    'ptsd134': 1,
#    'ptsd135': 1,
#    'ptsd136': 1,
#    'ptsd137': 1,
#    'ptsd138': 1,
#    'ptsd139': 1,
#    'ptsd140': 1,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 1,
#    'ptsd144': 1,
#    'ptsd145': 1,
#    'ptsd146': 1,
#    'ptsd147': 1,
#    'ptsd148': 1,
#    'ptsd149': 1,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 1,
#    'ptsd154': 1,
#    'ptsd155': 1,
#    'ptsd156': 1,
#    'ptsd157': 1,
#    'ptsd158': 1,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 1,
#    'ptsd165': 1,
#    'ptsd166': 1,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 1,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 1,
#    'ptsd175': 1,
#    'ptsd176': 1,
#    'ptsd177': 1,
#    'ptsd178': 1,
#    'ptsd179': 1,
#    'ptsd180': 1,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 1,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 1,
#    'ptsd198': 1,
#    'ptsd199': 1,
#    'ptsd200': 1,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 1,
#    'ptsd204': 1,
#    'ptsd205': 1,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 2,
#    'ptsd209': 2,
#    'ptsd210': 1,
#    'ptsd211': 2},
#   'veritas': 0.9036144578313253,
#   'veritas_prob': 0.9988538520352785,
#   'score': 0.37659098001791597},
#  {'subject_id': '95',
#   'responses': {'ptsd1': 5,
#    'ptsd2': 1,
#    'ptsd3': 1,
#    'ptsd4': 1,
#    'ptsd5': 4,
#    'ptsd6': 1,
#    'ptsd7': 1,
#    'ptsd8': 1,
#    'ptsd9': 2,
#    'ptsd10': 1,
#    'ptsd11': 1,
#    'ptsd12': 1,
#    'ptsd13': 2,
#    'ptsd14': 2,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 1,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 1,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 1,
#    'ptsd33': 1,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 1,
#    'ptsd37': 1,
#    'ptsd38': 1,
#    'ptsd39': 1,
#    'ptsd40': 1,
#    'ptsd41': 1,
#    'ptsd42': 1,
#    'ptsd43': 5,
#    'ptsd44': 1,
#    'ptsd45': 2,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 1,
#    'ptsd49': 1,
#    'ptsd50': 1,
#    'ptsd51': 1,
#    'ptsd52': 2,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 1,
#    'ptsd57': 2,
#    'ptsd58': 2,
#    'ptsd59': 2,
#    'ptsd60': 1,
#    'ptsd61': 2,
#    'ptsd62': 2,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 1,
#    'ptsd66': 1,
#    'ptsd67': 4,
#    'ptsd68': 1,
#    'ptsd69': 1,
#    'ptsd70': 1,
#    'ptsd71': 2,
#    'ptsd72': 1,
#    'ptsd73': 2,
#    'ptsd74': 2,
#    'ptsd75': 2,
#    'ptsd76': 2,
#    'ptsd77': 2,
#    'ptsd78': 2,
#    'ptsd79': 2,
#    'ptsd80': 2,
#    'ptsd81': 1,
#    'ptsd82': 1,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 1,
#    'ptsd86': 2,
#    'ptsd87': 2,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 2,
#    'ptsd91': 2,
#    'ptsd92': 2,
#    'ptsd93': 1,
#    'ptsd94': 2,
#    'ptsd95': 2,
#    'ptsd96': 2,
#    'ptsd97': 2,
#    'ptsd98': 1,
#    'ptsd99': 1,
#    'ptsd100': 2,
#    'ptsd101': 2,
#    'ptsd102': 2,
#    'ptsd103': 1,
#    'ptsd104': 2,
#    'ptsd105': 2,
#    'ptsd106': 2,
#    'ptsd107': 2,
#    'ptsd108': 1,
#    'ptsd109': 2,
#    'ptsd110': 2,
#    'ptsd111': 2,
#    'ptsd112': 1,
#    'ptsd113': 5,
#    'ptsd114': 1,
#    'ptsd115': 1,
#    'ptsd116': 2,
#    'ptsd117': 2,
#    'ptsd118': 2,
#    'ptsd119': 2,
#    'ptsd120': 2,
#    'ptsd121': 1,
#    'ptsd122': 1,
#    'ptsd123': 2,
#    'ptsd124': 2,
#    'ptsd125': 3,
#    'ptsd126': 2,
#    'ptsd127': 3,
#    'ptsd128': 1,
#    'ptsd129': 2,
#    'ptsd130': 2,
#    'ptsd131': 2,
#    'ptsd132': 1,
#    'ptsd133': 2,
#    'ptsd134': 1,
#    'ptsd135': 2,
#    'ptsd136': 2,
#    'ptsd137': 2,
#    'ptsd138': 2,
#    'ptsd139': 2,
#    'ptsd140': 2,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 1,
#    'ptsd144': 1,
#    'ptsd145': 2,
#    'ptsd146': 1,
#    'ptsd147': 1,
#    'ptsd148': 2,
#    'ptsd149': 2,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 2,
#    'ptsd153': 2,
#    'ptsd154': 2,
#    'ptsd155': 2,
#    'ptsd156': 2,
#    'ptsd157': 2,
#    'ptsd158': 2,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 1,
#    'ptsd165': 1,
#    'ptsd166': 1,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 2,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 2,
#    'ptsd175': 2,
#    'ptsd176': 2,
#    'ptsd177': 1,
#    'ptsd178': 1,
#    'ptsd179': 1,
#    'ptsd180': 1,
#    'ptsd181': 2,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 2,
#    'ptsd193': 2,
#    'ptsd194': 2,
#    'ptsd195': 2,
#    'ptsd196': 1,
#    'ptsd197': 2,
#    'ptsd198': 2,
#    'ptsd199': 2,
#    'ptsd200': 1,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 2,
#    'ptsd204': 1,
#    'ptsd205': 1,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 2,
#    'ptsd209': 2,
#    'ptsd210': 2,
#    'ptsd211': 2},
#   'veritas': 0.8811881188118812,
#   'veritas_prob': 0.9983252850232799,
#   'score': 0.4761716148245698},
#  {'subject_id': '258',
#   'responses': {'ptsd1': 2,
#    'ptsd2': 1,
#    'ptsd3': 1,
#    'ptsd4': 1,
#    'ptsd5': 1,
#    'ptsd6': 1,
#    'ptsd7': 1,
#    'ptsd8': 1,
#    'ptsd9': 1,
#    'ptsd10': 1,
#    'ptsd11': 1,
#    'ptsd12': 1,
#    'ptsd13': 1,
#    'ptsd14': 2,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 1,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 2,
#    'ptsd24': 2,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 2,
#    'ptsd33': 1,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 1,
#    'ptsd37': 1,
#    'ptsd38': 1,
#    'ptsd39': 1,
#    'ptsd40': 2,
#    'ptsd41': 1,
#    'ptsd42': 2,
#    'ptsd43': 1,
#    'ptsd44': 1,
#    'ptsd45': 2,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 1,
#    'ptsd49': 1,
#    'ptsd50': 1,
#    'ptsd51': 1,
#    'ptsd52': 1,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 2,
#    'ptsd57': 2,
#    'ptsd58': 2,
#    'ptsd59': 2,
#    'ptsd60': 1,
#    'ptsd61': 3,
#    'ptsd62': 3,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 1,
#    'ptsd66': 1,
#    'ptsd67': 1,
#    'ptsd68': 1,
#    'ptsd69': 1,
#    'ptsd70': 1,
#    'ptsd71': 1,
#    'ptsd72': 1,
#    'ptsd73': 1,
#    'ptsd74': 1,
#    'ptsd75': 1,
#    'ptsd76': 1,
#    'ptsd77': 1,
#    'ptsd78': 1,
#    'ptsd79': 1,
#    'ptsd80': 1,
#    'ptsd81': 2,
#    'ptsd82': 1,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 1,
#    'ptsd86': 1,
#    'ptsd87': 1,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 2,
#    'ptsd91': 2,
#    'ptsd92': 2,
#    'ptsd93': 1,
#    'ptsd94': 2,
#    'ptsd95': 1,
#    'ptsd96': 2,
#    'ptsd97': 2,
#    'ptsd98': 1,
#    'ptsd99': 2,
#    'ptsd100': 2,
#    'ptsd101': 2,
#    'ptsd102': 2,
#    'ptsd103': 1,
#    'ptsd104': 2,
#    'ptsd105': 2,
#    'ptsd106': 2,
#    'ptsd107': 1,
#    'ptsd108': 1,
#    'ptsd109': 2,
#    'ptsd110': 2,
#    'ptsd111': 1,
#    'ptsd112': 1,
#    'ptsd113': 1,
#    'ptsd114': 1,
#    'ptsd115': 3,
#    'ptsd116': 3,
#    'ptsd117': 1,
#    'ptsd118': 1,
#    'ptsd119': 1,
#    'ptsd120': 1,
#    'ptsd121': 1,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 1,
#    'ptsd125': 1,
#    'ptsd126': 1,
#    'ptsd127': 1,
#    'ptsd128': 1,
#    'ptsd129': 2,
#    'ptsd130': 1,
#    'ptsd131': 1,
#    'ptsd132': 1,
#    'ptsd133': 1,
#    'ptsd134': 1,
#    'ptsd135': 1,
#    'ptsd136': 1,
#    'ptsd137': 1,
#    'ptsd138': 1,
#    'ptsd139': 1,
#    'ptsd140': 1,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 1,
#    'ptsd144': 1,
#    'ptsd145': 1,
#    'ptsd146': 1,
#    'ptsd147': 1,
#    'ptsd148': 2,
#    'ptsd149': 1,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 2,
#    'ptsd154': 1,
#    'ptsd155': 2,
#    'ptsd156': 1,
#    'ptsd157': 1,
#    'ptsd158': 1,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 1,
#    'ptsd165': 2,
#    'ptsd166': 1,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 1,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 1,
#    'ptsd175': 1,
#    'ptsd176': 1,
#    'ptsd177': 1,
#    'ptsd178': 1,
#    'ptsd179': 1,
#    'ptsd180': 2,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 2,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 2,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 2,
#    'ptsd198': 1,
#    'ptsd199': 1,
#    'ptsd200': 2,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 1,
#    'ptsd204': 1,
#    'ptsd205': 1,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 2,
#    'ptsd209': 2,
#    'ptsd210': 2,
#    'ptsd211': 2},
#   'veritas': 0.9002932551319648,
#   'veritas_prob': 0.9987901764862555,
#   'score': 0.37019071881973625},
#  {'subject_id': '199',
#   'responses': {'ptsd1': 4,
#    'ptsd2': 2,
#    'ptsd3': 2,
#    'ptsd4': 4,
#    'ptsd5': 2,
#    'ptsd6': 2,
#    'ptsd7': 2,
#    'ptsd8': 3,
#    'ptsd9': 2,
#    'ptsd10': 2,
#    'ptsd11': 2,
#    'ptsd12': 2,
#    'ptsd13': 2,
#    'ptsd14': 4,
#    'ptsd15': 4,
#    'ptsd16': 3,
#    'ptsd17': 3,
#    'ptsd18': 3,
#    'ptsd19': 2,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 3,
#    'ptsd25': 4,
#    'ptsd26': 2,
#    'ptsd27': 2,
#    'ptsd28': 3,
#    'ptsd29': 3,
#    'ptsd30': 3,
#    'ptsd31': 2,
#    'ptsd32': 2,
#    'ptsd33': 2,
#    'ptsd34': 3,
#    'ptsd35': 1,
#    'ptsd36': 2,
#    'ptsd37': 3,
#    'ptsd38': 2,
#    'ptsd39': 2,
#    'ptsd40': 3,
#    'ptsd41': 1,
#    'ptsd42': 1,
#    'ptsd43': 2,
#    'ptsd44': 4,
#    'ptsd45': 2,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 3,
#    'ptsd49': 3,
#    'ptsd50': 3,
#    'ptsd51': 1,
#    'ptsd52': 3,
#    'ptsd53': 3,
#    'ptsd54': 1,
#    'ptsd55': 4,
#    'ptsd56': 1,
#    'ptsd57': 3,
#    'ptsd58': 4,
#    'ptsd59': 4,
#    'ptsd60': 2,
#    'ptsd61': 2,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 2,
#    'ptsd66': 1,
#    'ptsd67': 4,
#    'ptsd68': 2,
#    'ptsd69': 3,
#    'ptsd70': 2,
#    'ptsd71': 2,
#    'ptsd72': 2,
#    'ptsd73': 2,
#    'ptsd74': 1,
#    'ptsd75': 2,
#    'ptsd76': 2,
#    'ptsd77': 3,
#    'ptsd78': 2,
#    'ptsd79': 2,
#    'ptsd80': 2,
#    'ptsd81': 1,
#    'ptsd82': 2,
#    'ptsd83': 1,
#    'ptsd84': 1,
#    'ptsd85': 2,
#    'ptsd86': 2,
#    'ptsd87': 2,
#    'ptsd88': 2,
#    'ptsd89': 2,
#    'ptsd90': 3,
#    'ptsd91': 3,
#    'ptsd92': 2,
#    'ptsd93': 1,
#    'ptsd94': 2,
#    'ptsd95': 2,
#    'ptsd96': 2,
#    'ptsd97': 2,
#    'ptsd98': 2,
#    'ptsd99': 2,
#    'ptsd100': 2,
#    'ptsd101': 2,
#    'ptsd102': 2,
#    'ptsd103': 2,
#    'ptsd104': 2,
#    'ptsd105': 2,
#    'ptsd106': 3,
#    'ptsd107': 3,
#    'ptsd108': 2,
#    'ptsd109': 2,
#    'ptsd110': 2,
#    'ptsd111': 2,
#    'ptsd112': 1,
#    'ptsd113': 2,
#    'ptsd114': 1,
#    'ptsd115': 2,
#    'ptsd116': 2,
#    'ptsd117': 1,
#    'ptsd118': 2,
#    'ptsd119': 2,
#    'ptsd120': 2,
#    'ptsd121': 2,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 2,
#    'ptsd125': 3,
#    'ptsd126': 1,
#    'ptsd127': 2,
#    'ptsd128': 1,
#    'ptsd129': 1,
#    'ptsd130': 1,
#    'ptsd131': 2,
#    'ptsd132': 2,
#    'ptsd133': 2,
#    'ptsd134': 1,
#    'ptsd135': 2,
#    'ptsd136': 1,
#    'ptsd137': 2,
#    'ptsd138': 2,
#    'ptsd139': 2,
#    'ptsd140': 2,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 2,
#    'ptsd144': 1,
#    'ptsd145': 1,
#    'ptsd146': 1,
#    'ptsd147': 2,
#    'ptsd148': 3,
#    'ptsd149': 2,
#    'ptsd150': 2,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 2,
#    'ptsd154': 2,
#    'ptsd155': 2,
#    'ptsd156': 2,
#    'ptsd157': 2,
#    'ptsd158': 2,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 2,
#    'ptsd165': 3,
#    'ptsd166': 2,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 2,
#    'ptsd170': 3,
#    'ptsd171': 1,
#    'ptsd172': 2,
#    'ptsd173': 2,
#    'ptsd174': 2,
#    'ptsd175': 2,
#    'ptsd176': 1,
#    'ptsd177': 1,
#    'ptsd178': 2,
#    'ptsd179': 3,
#    'ptsd180': 2,
#    'ptsd181': 2,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 2,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 1,
#    'ptsd198': 1,
#    'ptsd199': 1,
#    'ptsd200': 2,
#    'ptsd201': 3,
#    'ptsd202': 2,
#    'ptsd203': 2,
#    'ptsd204': 2,
#    'ptsd205': 3,
#    'ptsd206': 1,
#    'ptsd207': 1,
#    'ptsd208': 2,
#    'ptsd209': 2,
#    'ptsd210': 2,
#    'ptsd211': 2},
#   'veritas': 0.7726947819871337,
#   'veritas_prob': 0.9796581756383749,
#   'score': 0.7121877437029277},
#  {'subject_id': '191',
#   'responses': {'ptsd1': 1,
#    'ptsd2': 1,
#    'ptsd3': 3,
#    'ptsd4': 1,
#    'ptsd5': 1,
#    'ptsd6': 2,
#    'ptsd7': 2,
#    'ptsd8': 2,
#    'ptsd9': 1,
#    'ptsd10': 1,
#    'ptsd11': 3,
#    'ptsd12': 1,
#    'ptsd13': 2,
#    'ptsd14': 2,
#    'ptsd15': 1,
#    'ptsd16': 1,
#    'ptsd17': 1,
#    'ptsd18': 2,
#    'ptsd19': 1,
#    'ptsd20': 1,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 2,
#    'ptsd25': 1,
#    'ptsd26': 1,
#    'ptsd27': 2,
#    'ptsd28': 2,
#    'ptsd29': 1,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 2,
#    'ptsd33': 2,
#    'ptsd34': 1,
#    'ptsd35': 1,
#    'ptsd36': 2,
#    'ptsd37': 2,
#    'ptsd38': 1,
#    'ptsd39': 2,
#    'ptsd40': 1,
#    'ptsd41': 1,
#    'ptsd42': 3,
#    'ptsd43': 4,
#    'ptsd44': 1,
#    'ptsd45': 2,
#    'ptsd46': 1,
#    'ptsd47': 1,
#    'ptsd48': 2,
#    'ptsd49': 2,
#    'ptsd50': 2,
#    'ptsd51': 1,
#    'ptsd52': 2,
#    'ptsd53': 2,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 1,
#    'ptsd57': 2,
#    'ptsd58': 2,
#    'ptsd59': 2,
#    'ptsd60': 3,
#    'ptsd61': 2,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 1,
#    'ptsd66': 1,
#    'ptsd67': 2,
#    'ptsd68': 1,
#    'ptsd69': 1,
#    'ptsd70': 1,
#    'ptsd71': 2,
#    'ptsd72': 2,
#    'ptsd73': 2,
#    'ptsd74': 2,
#    'ptsd75': 1,
#    'ptsd76': 2,
#    'ptsd77': 2,
#    'ptsd78': 1,
#    'ptsd79': 2,
#    'ptsd80': 3,
#    'ptsd81': 2,
#    'ptsd82': 2,
#    'ptsd83': 1,
#    'ptsd84': 2,
#    'ptsd85': 2,
#    'ptsd86': 1,
#    'ptsd87': 1,
#    'ptsd88': 1,
#    'ptsd89': 1,
#    'ptsd90': 2,
#    'ptsd91': 2,
#    'ptsd92': 2,
#    'ptsd93': 1,
#    'ptsd94': 2,
#    'ptsd95': 1,
#    'ptsd96': 2,
#    'ptsd97': 2,
#    'ptsd98': 2,
#    'ptsd99': 2,
#    'ptsd100': 2,
#    'ptsd101': 2,
#    'ptsd102': 2,
#    'ptsd103': 2,
#    'ptsd104': 1,
#    'ptsd105': 2,
#    'ptsd106': 2,
#    'ptsd107': 3,
#    'ptsd108': 3,
#    'ptsd109': 2,
#    'ptsd110': 2,
#    'ptsd111': 2,
#    'ptsd112': 1,
#    'ptsd113': 2,
#    'ptsd114': 2,
#    'ptsd115': 1,
#    'ptsd116': 2,
#    'ptsd117': 1,
#    'ptsd118': 1,
#    'ptsd119': 1,
#    'ptsd120': 2,
#    'ptsd121': 2,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 2,
#    'ptsd125': 2,
#    'ptsd126': 2,
#    'ptsd127': 3,
#    'ptsd128': 3,
#    'ptsd129': 1,
#    'ptsd130': 3,
#    'ptsd131': 3,
#    'ptsd132': 2,
#    'ptsd133': 1,
#    'ptsd134': 2,
#    'ptsd135': 1,
#    'ptsd136': 1,
#    'ptsd137': 2,
#    'ptsd138': 2,
#    'ptsd139': 2,
#    'ptsd140': 2,
#    'ptsd141': 1,
#    'ptsd142': 1,
#    'ptsd143': 2,
#    'ptsd144': 2,
#    'ptsd145': 2,
#    'ptsd146': 2,
#    'ptsd147': 2,
#    'ptsd148': 1,
#    'ptsd149': 1,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 2,
#    'ptsd154': 2,
#    'ptsd155': 2,
#    'ptsd156': 1,
#    'ptsd157': 2,
#    'ptsd158': 2,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 2,
#    'ptsd163': 2,
#    'ptsd164': 3,
#    'ptsd165': 3,
#    'ptsd166': 3,
#    'ptsd167': 1,
#    'ptsd168': 1,
#    'ptsd169': 2,
#    'ptsd170': 2,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 2,
#    'ptsd174': 3,
#    'ptsd175': 3,
#    'ptsd176': 1,
#    'ptsd177': 3,
#    'ptsd178': 2,
#    'ptsd179': 3,
#    'ptsd180': 3,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 1,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 2,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 3,
#    'ptsd196': 2,
#    'ptsd197': 3,
#    'ptsd198': 3,
#    'ptsd199': 1,
#    'ptsd200': 1,
#    'ptsd201': 3,
#    'ptsd202': 2,
#    'ptsd203': 2,
#    'ptsd204': 2,
#    'ptsd205': 2,
#    'ptsd206': 4,
#    'ptsd207': 4,
#    'ptsd208': 4,
#    'ptsd209': 4,
#    'ptsd210': 3,
#    'ptsd211': 2},
#   'veritas': 0.847953216374269,
#   'veritas_prob': 0.9968500783655289,
#   'score': 0.5615576798198226},
#  {'subject_id': '228',
#   'responses': {'ptsd1': 1,
#    'ptsd2': 1,
#    'ptsd3': 2,
#    'ptsd4': 2,
#    'ptsd5': 3,
#    'ptsd6': 2,
#    'ptsd7': 3,
#    'ptsd8': 3,
#    'ptsd9': 2,
#    'ptsd10': 3,
#    'ptsd11': 3,
#    'ptsd12': 1,
#    'ptsd13': 1,
#    'ptsd14': 2,
#    'ptsd15': 3,
#    'ptsd16': 1,
#    'ptsd17': 2,
#    'ptsd18': 3,
#    'ptsd19': 1,
#    'ptsd20': 2,
#    'ptsd21': 1,
#    'ptsd22': 1,
#    'ptsd23': 1,
#    'ptsd24': 3,
#    'ptsd25': 3,
#    'ptsd26': 4,
#    'ptsd27': 1,
#    'ptsd28': 1,
#    'ptsd29': 2,
#    'ptsd30': 1,
#    'ptsd31': 1,
#    'ptsd32': 3,
#    'ptsd33': 2,
#    'ptsd34': 4,
#    'ptsd35': 2,
#    'ptsd36': 3,
#    'ptsd37': 3,
#    'ptsd38': 3,
#    'ptsd39': 2,
#    'ptsd40': 3,
#    'ptsd41': 3,
#    'ptsd42': 1,
#    'ptsd43': 3,
#    'ptsd44': 1,
#    'ptsd45': 3,
#    'ptsd46': 1,
#    'ptsd47': 2,
#    'ptsd48': 3,
#    'ptsd49': 2,
#    'ptsd50': 3,
#    'ptsd51': 1,
#    'ptsd52': 1,
#    'ptsd53': 1,
#    'ptsd54': 1,
#    'ptsd55': 1,
#    'ptsd56': 1,
#    'ptsd57': 3,
#    'ptsd58': 2,
#    'ptsd59': 2,
#    'ptsd60': 3,
#    'ptsd61': 2,
#    'ptsd62': 1,
#    'ptsd63': 1,
#    'ptsd64': 1,
#    'ptsd65': 3,
#    'ptsd66': 1,
#    'ptsd67': 1,
#    'ptsd68': 2,
#    'ptsd69': 3,
#    'ptsd70': 2,
#    'ptsd71': 1,
#    'ptsd72': 2,
#    'ptsd73': 1,
#    'ptsd74': 2,
#    'ptsd75': 3,
#    'ptsd76': 1,
#    'ptsd77': 3,
#    'ptsd78': 3,
#    'ptsd79': 3,
#    'ptsd80': 3,
#    'ptsd81': 1,
#    'ptsd82': 1,
#    'ptsd83': 3,
#    'ptsd84': 1,
#    'ptsd85': 2,
#    'ptsd86': 2,
#    'ptsd87': 3,
#    'ptsd88': 2,
#    'ptsd89': 1,
#    'ptsd90': 2,
#    'ptsd91': 3,
#    'ptsd92': 2,
#    'ptsd93': 3,
#    'ptsd94': 3,
#    'ptsd95': 2,
#    'ptsd96': 3,
#    'ptsd97': 2,
#    'ptsd98': 1,
#    'ptsd99': 1,
#    'ptsd100': 3,
#    'ptsd101': 1,
#    'ptsd102': 1,
#    'ptsd103': 2,
#    'ptsd104': 2,
#    'ptsd105': 3,
#    'ptsd106': 1,
#    'ptsd107': 2,
#    'ptsd108': 2,
#    'ptsd109': 3,
#    'ptsd110': 2,
#    'ptsd111': 2,
#    'ptsd112': 2,
#    'ptsd113': 1,
#    'ptsd114': 2,
#    'ptsd115': 1,
#    'ptsd116': 1,
#    'ptsd117': 2,
#    'ptsd118': 1,
#    'ptsd119': 3,
#    'ptsd120': 2,
#    'ptsd121': 3,
#    'ptsd122': 1,
#    'ptsd123': 3,
#    'ptsd124': 3,
#    'ptsd125': 1,
#    'ptsd126': 1,
#    'ptsd127': 2,
#    'ptsd128': 3,
#    'ptsd129': 1,
#    'ptsd130': 3,
#    'ptsd131': 1,
#    'ptsd132': 3,
#    'ptsd133': 2,
#    'ptsd134': 3,
#    'ptsd135': 3,
#    'ptsd136': 1,
#    'ptsd137': 1,
#    'ptsd138': 3,
#    'ptsd139': 3,
#    'ptsd140': 3,
#    'ptsd141': 1,
#    'ptsd142': 3,
#    'ptsd143': 2,
#    'ptsd144': 4,
#    'ptsd145': 4,
#    'ptsd146': 1,
#    'ptsd147': 3,
#    'ptsd148': 1,
#    'ptsd149': 2,
#    'ptsd150': 1,
#    'ptsd151': 1,
#    'ptsd152': 2,
#    'ptsd153': 3,
#    'ptsd154': 3,
#    'ptsd155': 1,
#    'ptsd156': 3,
#    'ptsd157': 1,
#    'ptsd158': 2,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 1,
#    'ptsd163': 1,
#    'ptsd164': 2,
#    'ptsd165': 3,
#    'ptsd166': 2,
#    'ptsd167': 2,
#    'ptsd168': 1,
#    'ptsd169': 1,
#    'ptsd170': 1,
#    'ptsd171': 1,
#    'ptsd172': 1,
#    'ptsd173': 1,
#    'ptsd174': 1,
#    'ptsd175': 1,
#    'ptsd176': 1,
#    'ptsd177': 2,
#    'ptsd178': 1,
#    'ptsd179': 3,
#    'ptsd180': 1,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 2,
#    'ptsd185': 2,
#    'ptsd186': 1,
#    'ptsd187': 2,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 1,
#    'ptsd193': 2,
#    'ptsd194': 1,
#    'ptsd195': 1,
#    'ptsd196': 1,
#    'ptsd197': 1,
#    'ptsd198': 1,
#    'ptsd199': 2,
#    'ptsd200': 1,
#    'ptsd201': 1,
#    'ptsd202': 1,
#    'ptsd203': 2,
#    'ptsd204': 2,
#    'ptsd205': 4,
#    'ptsd206': 2,
#    'ptsd207': 1,
#    'ptsd208': 2,
#    'ptsd209': 1,
#    'ptsd210': 2,
#    'ptsd211': 2},
#   'veritas': 0.8067729083665338,
#   'veritas_prob': 0.9920058573370228,
#   'score': 0.7302072513997666},
#  {'subject_id': '141',
#   'responses': {'ptsd1': 5,
#    'ptsd2': 2,
#    'ptsd3': 1,
#    'ptsd4': 3,
#    'ptsd5': 3,
#    'ptsd6': 4,
#    'ptsd7': 3,
#    'ptsd8': 5,
#    'ptsd9': 1,
#    'ptsd10': 2,
#    'ptsd11': 4,
#    'ptsd12': 4,
#    'ptsd13': 4,
#    'ptsd14': 4,
#    'ptsd15': 5,
#    'ptsd16': 4,
#    'ptsd17': 5,
#    'ptsd18': 5,
#    'ptsd19': 5,
#    'ptsd20': 1,
#    'ptsd21': 5,
#    'ptsd22': 4,
#    'ptsd23': 3,
#    'ptsd24': 4,
#    'ptsd25': 4,
#    'ptsd26': 1,
#    'ptsd27': 4,
#    'ptsd28': 4,
#    'ptsd29': 5,
#    'ptsd30': 5,
#    'ptsd31': 5,
#    'ptsd32': 2,
#    'ptsd33': 4,
#    'ptsd34': 3,
#    'ptsd35': 1,
#    'ptsd36': 4,
#    'ptsd37': 4,
#    'ptsd38': 1,
#    'ptsd39': 4,
#    'ptsd40': 4,
#    'ptsd41': 4,
#    'ptsd42': 4,
#    'ptsd43': 2,
#    'ptsd44': 5,
#    'ptsd45': 3,
#    'ptsd46': 4,
#    'ptsd47': 1,
#    'ptsd48': 4,
#    'ptsd49': 4,
#    'ptsd50': 4,
#    'ptsd51': 1,
#    'ptsd52': 4,
#    'ptsd53': 4,
#    'ptsd54': 3,
#    'ptsd55': 5,
#    'ptsd56': 3,
#    'ptsd57': 2,
#    'ptsd58': 4,
#    'ptsd59': 5,
#    'ptsd60': 3,
#    'ptsd61': 4,
#    'ptsd62': 4,
#    'ptsd63': 4,
#    'ptsd64': 1,
#    'ptsd65': 4,
#    'ptsd66': 3,
#    'ptsd67': 1,
#    'ptsd68': 1,
#    'ptsd69': 3,
#    'ptsd70': 5,
#    'ptsd71': 4,
#    'ptsd72': 4,
#    'ptsd73': 4,
#    'ptsd74': 1,
#    'ptsd75': 1,
#    'ptsd76': 3,
#    'ptsd77': 2,
#    'ptsd78': 2,
#    'ptsd79': 2,
#    'ptsd80': 5,
#    'ptsd81': 5,
#    'ptsd82': 4,
#    'ptsd83': 2,
#    'ptsd84': 4,
#    'ptsd85': 4,
#    'ptsd86': 1,
#    'ptsd87': 4,
#    'ptsd88': 1,
#    'ptsd89': 2,
#    'ptsd90': 2,
#    'ptsd91': 3,
#    'ptsd92': 4,
#    'ptsd93': 3,
#    'ptsd94': 4,
#    'ptsd95': 1,
#    'ptsd96': 4,
#    'ptsd97': 5,
#    'ptsd98': 2,
#    'ptsd99': 3,
#    'ptsd100': 2,
#    'ptsd101': 3,
#    'ptsd102': 5,
#    'ptsd103': 2,
#    'ptsd104': 4,
#    'ptsd105': 2,
#    'ptsd106': 3,
#    'ptsd107': 4,
#    'ptsd108': 2,
#    'ptsd109': 4,
#    'ptsd110': 2,
#    'ptsd111': 5,
#    'ptsd112': 1,
#    'ptsd113': 3,
#    'ptsd114': 2,
#    'ptsd115': 1,
#    'ptsd116': 5,
#    'ptsd117': 4,
#    'ptsd118': 1,
#    'ptsd119': 2,
#    'ptsd120': 3,
#    'ptsd121': 2,
#    'ptsd122': 1,
#    'ptsd123': 1,
#    'ptsd124': 4,
#    'ptsd125': 3,
#    'ptsd126': 3,
#    'ptsd127': 4,
#    'ptsd128': 3,
#    'ptsd129': 4,
#    'ptsd130': 5,
#    'ptsd131': 2,
#    'ptsd132': 3,
#    'ptsd133': 3,
#    'ptsd134': 3,
#    'ptsd135': 1,
#    'ptsd136': 4,
#    'ptsd137': 2,
#    'ptsd138': 4,
#    'ptsd139': 3,
#    'ptsd140': 4,
#    'ptsd141': 3,
#    'ptsd142': 5,
#    'ptsd143': 3,
#    'ptsd144': 4,
#    'ptsd145': 3,
#    'ptsd146': 1,
#    'ptsd147': 4,
#    'ptsd148': 4,
#    'ptsd149': 1,
#    'ptsd150': 3,
#    'ptsd151': 1,
#    'ptsd152': 1,
#    'ptsd153': 4,
#    'ptsd154': 4,
#    'ptsd155': 4,
#    'ptsd156': 3,
#    'ptsd157': 2,
#    'ptsd158': 3,
#    'ptsd159': 1,
#    'ptsd160': 1,
#    'ptsd161': 1,
#    'ptsd162': 3,
#    'ptsd163': 3,
#    'ptsd164': 3,
#    'ptsd165': 3,
#    'ptsd166': 3,
#    'ptsd167': 2,
#    'ptsd168': 4,
#    'ptsd169': 4,
#    'ptsd170': 4,
#    'ptsd171': 3,
#    'ptsd172': 2,
#    'ptsd173': 3,
#    'ptsd174': 4,
#    'ptsd175': 4,
#    'ptsd176': 1,
#    'ptsd177': 3,
#    'ptsd178': 1,
#    'ptsd179': 4,
#    'ptsd180': 3,
#    'ptsd181': 1,
#    'ptsd182': 1,
#    'ptsd183': 1,
#    'ptsd184': 1,
#    'ptsd185': 4,
#    'ptsd186': 1,
#    'ptsd187': 1,
#    'ptsd188': 1,
#    'ptsd189': 1,
#    'ptsd190': 1,
#    'ptsd191': 1,
#    'ptsd192': 4,
#    'ptsd193': 1,
#    'ptsd194': 1,
#    'ptsd195': 4,
#    'ptsd196': 3,
#    'ptsd197': 4,
#    'ptsd198': 3,
#    'ptsd199': 1,
#    'ptsd200': 5,
#    'ptsd201': 5,
#    'ptsd202': 4,
#    'ptsd203': 2,
#    'ptsd204': 5,
#    'ptsd205': 3,
#    'ptsd206': 2,
#    'ptsd207': 4,
#    'ptsd208': 3,
#    'ptsd209': 5,
#    'ptsd210': 2,
#    'ptsd211': 4},
#   'veritas': 0.7178329571106095,
#   'veritas_prob': 0.8704658251545969,
#   'score': 1.2584590050365732},
#  {'subject_id': '188',
#   'responses': {'ptsd1': 4,
#    'ptsd2': 1,
#    'ptsd3': 3,
#    'ptsd4': 3,
#    'ptsd5': 4,
#    'ptsd6': 3,
#    'ptsd7': 4,
#    'ptsd8': 4,
#    'ptsd9': 2,
#    'ptsd10': 4,
#    'ptsd11': 3,
#    'ptsd12': 3,
#    'ptsd13': 5,
#    'ptsd14': 4,
#    'ptsd15': 4,
#    'ptsd16': 3,
#    'ptsd17': 5,
#    'ptsd18': 3,
#    'ptsd19': 4,
#    'ptsd20': 4,
#    'ptsd21': 2,
#    'ptsd22': 3,
#    'ptsd23': 4,
#    'ptsd24': 3,
#    'ptsd25': 3,
#    'ptsd26': 3,
#    'ptsd27': 3,
#    'ptsd28': 3,
#    'ptsd29': 3,
#    'ptsd30': 4,
#    'ptsd31': 4,
#    'ptsd32': 3,
#    'ptsd33': 3,
#    'ptsd34': 3,
#    'ptsd35': 3,
#    'ptsd36': 3,
#    'ptsd37': 3,
#    'ptsd38': 3,
#    'ptsd39': 4,
#    'ptsd40': 3,
#    'ptsd41': 3,
#    'ptsd42': 3,
#    'ptsd43': 3,
#    'ptsd44': 4,
#    'ptsd45': 1,
#    'ptsd46': 2,
#    'ptsd47': 4,
#    'ptsd48': 3,
#    'ptsd49': 4,
#    'ptsd50': 4,
#    'ptsd51': 3,
#    'ptsd52': 4,
#    'ptsd53': 4,
#    'ptsd54': 4,
#    'ptsd55': 5,
#    'ptsd56': 3,
#    'ptsd57': 2,
#    'ptsd58': 5,
#    'ptsd59': 5,
#    'ptsd60': 4,
#    'ptsd61': 5,
#    'ptsd62': 3,
#    'ptsd63': 4,
#    'ptsd64': 3,
#    'ptsd65': 4,
#    'ptsd66': 4,
#    'ptsd67': 1,
#    'ptsd68': 3,
#    'ptsd69': 4,
#    'ptsd70': 5,
#    'ptsd71': 5,
#    'ptsd72': 5,
#    'ptsd73': 5,
#    'ptsd74': 5,
#    'ptsd75': 5,
#    'ptsd76': 4,
#    'ptsd77': 2,
#    'ptsd78': 5,
#    'ptsd79': 4,
#    'ptsd80': 5,
#    'ptsd81': 5,
#    'ptsd82': 4,
#    'ptsd83': 3,
#    'ptsd84': 4,
#    'ptsd85': 5,
#    'ptsd86': 5,
#    'ptsd87': 5,
#    'ptsd88': 5,
#    'ptsd89': 3,
#    'ptsd90': 2,
#    'ptsd91': 4,
#    'ptsd92': 4,
#    'ptsd93': 4,
#    'ptsd94': 4,
#    'ptsd95': 4,
#    'ptsd96': 5,
#    'ptsd97': 5,
#    'ptsd98': 4,
#    'ptsd99': 4,
#    'ptsd100': 2,
#    'ptsd101': 5,
#    'ptsd102': 5,
#    'ptsd103': 4,
#    'ptsd104': 5,
#    'ptsd105': 2,
#    'ptsd106': 4,
#    'ptsd107': 4,
#    'ptsd108': 4,
#    'ptsd109': 4,
#    'ptsd110': 2,
#    'ptsd111': 5,
#    'ptsd112': 3,
#    'ptsd113': 1,
#    'ptsd114': 3,
#    'ptsd115': 1,
#    'ptsd116': 1,
#    'ptsd117': 3,
#    'ptsd118': 4,
#    'ptsd119': 4,
#    'ptsd120': 4,
#    'ptsd121': 3,
#    'ptsd122': 2,
#    'ptsd123': 4,
#    'ptsd124': 4,
#    'ptsd125': 3,
#    'ptsd126': 4,
#    'ptsd127': 4,
#    'ptsd128': 4,
#    'ptsd129': 3,
#    'ptsd130': 4,
#    'ptsd131': 4,
#    'ptsd132': 4,
#    'ptsd133': 4,
#    'ptsd134': 3,
#    'ptsd135': 3,
#    'ptsd136': 4,
#    'ptsd137': 4,
#    'ptsd138': 4,
#    'ptsd139': 4,
#    'ptsd140': 5,
#    'ptsd141': 4,
#    'ptsd142': 5,
#    'ptsd143': 5,
#    'ptsd144': 4,
#    'ptsd145': 4,
#    'ptsd146': 3,
#    'ptsd147': 4,
#    'ptsd148': 4,
#    'ptsd149': 5,
#    'ptsd150': 4,
#    'ptsd151': 2,
#    'ptsd152': 3,
#    'ptsd153': 4,
#    'ptsd154': 4,
#    'ptsd155': 4,
#    'ptsd156': 4,
#    'ptsd157': 3,
#    'ptsd158': 5,
#    'ptsd159': 5,
#    'ptsd160': 5,
#    'ptsd161': 4,
#    'ptsd162': 3,
#    'ptsd163': 4,
#    'ptsd164': 4,
#    'ptsd165': 4,
#    'ptsd166': 4,
#    'ptsd167': 4,
#    'ptsd168': 4,
#    'ptsd169': 5,
#    'ptsd170': 5,
#    'ptsd171': 4,
#    'ptsd172': 4,
#    'ptsd173': 4,
#    'ptsd174': 5,
#    'ptsd175': 5,
#    'ptsd176': 5,
#    'ptsd177': 4,
#    'ptsd178': 3,
#    'ptsd179': 4,
#    'ptsd180': 4,
#    'ptsd181': 4,
#    'ptsd182': 4,
#    'ptsd183': 5,
#    'ptsd184': 5,
#    'ptsd185': 4,
#    'ptsd186': 4,
#    'ptsd187': 4,
#    'ptsd188': 4,
#    'ptsd189': 3,
#    'ptsd190': 2,
#    'ptsd191': 3,
#    'ptsd192': 4,
#    'ptsd193': 5,
#    'ptsd194': 4,
#    'ptsd195': 5,
#    'ptsd196': 5,
#    'ptsd197': 5,
#    'ptsd198': 5,
#    'ptsd199': 3,
#    'ptsd200': 5,
#    'ptsd201': 5,
#    'ptsd202': 5,
#    'ptsd203': 3,
#    'ptsd204': 3,
#    'ptsd205': 4,
#    'ptsd206': 3,
#    'ptsd207': 2,
#    'ptsd208': 5,
#    'ptsd209': 5,
#    'ptsd210': 2,
#    'ptsd211': 5},
#   'veritas': 0.6794462193823216,
#   'veritas_prob': 0.5523037055423642,
#   'score': 1.8442158843753629},
#  {'subject_id': '188xx',
#   'responses': {'ptsd1': 4,
#    'ptsd2': 1,
#    'ptsd3': 3,
#    'ptsd4': 3,
#    'ptsd5': 4,
#    'ptsd6': 3,
#    'ptsd7': 4,
#    'ptsd8': 4,
#    'ptsd9': 2,
#    'ptsd10': 4,
#    'ptsd11': 3,
#    'ptsd12': 3,
#    'ptsd13': 5,
#    'ptsd14': 4,
#    'ptsd15': 4,
#    'ptsd16': 3,
#    'ptsd17': 5,
#    'ptsd18': 3,
#    'ptsd19': 4,
#    'ptsd20': 4,
#    'ptsd21': 2,
#    'ptsd22': 3,
#    'ptsd23': 4,
#    'ptsd24': 3,
#    'ptsd25': 3,
#    'ptsd26': 3,
#    'ptsd27': 3,
#    'ptsd28': 3,
#    'ptsd29': 3,
#    'ptsd30': 4,
#    'ptsd31': 4,
#    'ptsd32': 3,
#    'ptsd33': 3,
#    'ptsd34': 3,
#    'ptsd35': 3,
#    'ptsd36': 3,
#    'ptsd37': 3,
#    'ptsd38': 3,
#    'ptsd39': 4,
#    'ptsd40': 3,
#    'ptsd41': 3,
#    'ptsd42': 3,
#    'ptsd125': 3,
#    'ptsd126': 4,
#    'ptsd127': 4,
#    'ptsd128': 4,
#    'ptsd129': 3,
#    'ptsd130': 4,
#    'ptsd131': 4,
#    'ptsd132': 4,
#    'ptsd133': 4,
#    'ptsd134': 3,
#    'ptsd135': 3,
#    'ptsd136': 4,
#    'ptsd137': 4,
#    'ptsd138': 4,
#    'ptsd139': 4,
#    'ptsd140': 5,
#    'ptsd141': 4,
#    'ptsd142': 5,
#    'ptsd143': 5,
#    'ptsd144': 4,
#    'ptsd145': 4,
#    'ptsd146': 3,
#    'ptsd147': 4,
#    'ptsd148': 4,
#    'ptsd149': 5,
#    'ptsd150': 4,
#    'ptsd151': 2,
#    'ptsd152': 3,
#    'ptsd153': 4,
#    'ptsd154': 4,
#    'ptsd155': 4,
#    'ptsd156': 4,
#    'ptsd157': 3,
#    'ptsd158': 5,
#    'ptsd159': 5,
#    'ptsd160': 5,
#    'ptsd161': 4,
#    'ptsd162': 3,
#    'ptsd163': 4,
#    'ptsd164': 4,
#    'ptsd165': 4,
#    'ptsd166': 4,
#    'ptsd167': 4,
#    'ptsd168': 4,
#    'ptsd169': 5,
#    'ptsd170': 5,
#    'ptsd171': 4,
#    'ptsd172': 4,
#    'ptsd173': 4,
#    'ptsd174': 5,
#    'ptsd175': 5,
#    'ptsd176': 5,
#    'ptsd177': 4,
#    'ptsd178': 3,
#    'ptsd179': 4,
#    'ptsd180': 4,
#    'ptsd181': 4,
#    'ptsd182': 4,
#    'ptsd183': 5,
#    'ptsd184': 5,
#    'ptsd185': 4,
#    'ptsd186': 4,
#    'ptsd187': 4,
#    'ptsd188': 4,
#    'ptsd189': 3,
#    'ptsd190': 2,
#    'ptsd191': 3,
#    'ptsd192': 4,
#    'ptsd193': 5,
#    'ptsd194': 4,
#    'ptsd195': 5,
#    'ptsd196': 5,
#    'ptsd197': 5,
#    'ptsd198': 5,
#    'ptsd211': 5},
#   'veritas': 0.6751824817518247,
#   'veritas_prob': 0.5035324830717995,
#   'score': 1.7520523951116802}]

# %% [raw]
# # save veritas model
# veritas_ptsd={}
# veritas_ptsd['version']='0.0.1'
# veritas_ptsd['model']=model
# veritas_ptsd['t_distribution']=t_distribution
# import dill as pickle  # Dill functions similarly to pickle
# import gzip
# with gzip.open('veritas_ptsd.pkl.gz', 'wb') as f:
#     pickle.dump(veritas_ptsd, f)

# %%
import json
filepath='/home/ishanu/Dropbox/paraknowledge/paraknowledgecorp/webpage/veritas/responses2.json'
with open(filepath, 'r') as file:
    data = json.load(file)
data=data['questionnaireResponses']

# %%
reveal(data,veritas_ptsd,modelneg=modelneg)
