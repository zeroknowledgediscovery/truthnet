# %%
import glob
from datetime import datetime

import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.stats.api as sms
import tikzplotlib as tpl
import xgboost as xgb
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    PrecisionRecallDisplay,
    RocCurveDisplay,
    auc,
    mean_squared_error,
    precision_recall_curve,
    r2_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from zedstat import zedstat

from truthnet import truthnet

# %%
glob.glob("rf_auc_res/auc_df_rf__random*.csv")
# Out:
# ['rf_auc_res/auc_df_rf__random_order_2023-07-29 00:51:05.618178.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 13:15:53.385783.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 10:54:00.502779.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-29 02:02:19.775968.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 23:15:08.861486.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-29 01:14:45.296259.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 16:25:40.044463.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 12:27:42.601795.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-29 00:27:28.584389.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 11:40:48.522978.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 14:49:56.793016.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 23:39:28.749820.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 13:39:30.004627.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 22:28:03.084469.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 12:51:38.912429.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 11:17:18.681155.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 14:03:09.868177.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 10:19:48.689452.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 14:26:38.212257.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 12:04:30.688370.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-29 01:38:31.311383.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 15:37:33.826914.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-29 00:03:51.227765.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 16:01:42.940312.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 22:51:21.149870.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 16:49:57.660083.csv',
#  'rf_auc_res/auc_df_rf__random_order_2023-07-28 15:13:47.158522.csv']

# %%
len(glob.glob("rf_auc_res/auc_df_rf__random*.csv"))
# Out:
# 27

# %%
rf = pd.concat(
    [pd.read_csv(df) for df in glob.glob("rf_auc_res/auc_df_rf__random*.csv")]
)

# %%
rf
# Out:
#     questions asked       auc     z_auc  z_auc_lb  z_auc_ub
# 0                 1  0.772685  0.772685  0.772685  0.772685
# 1                 6  0.807692  0.848025  0.808407  0.887714
# 2                11  0.836866  0.863935  0.818913  0.909001
# 3                16  0.937558  0.939448  0.914231  0.964674
# 4                21  0.968779  0.951621  0.932494  0.970766
# ..              ...       ...       ...       ...       ...
# 16               81  0.999081  0.999081  0.999081  0.999081
# 17               86  1.000000  0.500000  0.417720  0.582588
# 18               91  1.000000  0.500000  0.417720  0.582588
# 19               96  0.998157  0.998157  0.998157  0.998157
# 20              101  1.000000  0.500000  0.417720  0.582588
#
# [567 rows x 5 columns]

# %%
conf = 0.95

rf_auc_ci_var = rf.groupby(["questions asked"], as_index=False).agg(
    mean=pd.NamedAgg(column="auc", aggfunc="mean"),
    var=pd.NamedAgg(column="auc", aggfunc="var"),
    ci=pd.NamedAgg(
        column="auc",
        aggfunc=lambda x: sms.DescrStatsW(x).tconfint_mean(alpha=1 - conf),
    ),
)

# %%
rf_auc_ci_var.assign(
    lower=lambda x: [c[0] for c in x["ci"]], upper=lambda x: [c[1] for c in x["ci"]]
).drop("ci", axis="columns").to_csv("rf_ptsd_random_order_auc_ci_var.csv", index=False)

# %%
fig, ax = plt.subplots()
lgbm_auc_ci_var.plot(x="questions asked", y="mean", ax=ax)
ax.fill_between(
    lgbm_auc_ci_var["questions asked"],
    [x[0] for x in lgbm_auc_ci_var["ci"]],
    [x[1] for x in lgbm_auc_ci_var["ci"]],
    alpha=0.25,
)

# %%
fig, ax = plt.subplots()
lgbm_auc_ci_var.plot(x="questions asked", y="mean", ax=ax)
ax.fill_between(
    lgbm_auc_ci_var["questions asked"],
    [x[0] for x in lgbm_auc_ci_var["ci"]],
    [x[1] for x in lgbm_auc_ci_var["ci"]],
    alpha=0.25,
)

# %%
g = sns.relplot(
    data=lgbm,
    x="questions asked",
    y="auc",
    kind="line",
)

# %%
def _sns_plot_to_df(ax, line_idx=0):
    # get mean
    mean_p_df = pd.DataFrame(
        data={0: ax.lines[line_idx].get_xdata(), 1: ax.lines[0].get_ydata()}
    )

    # get upper/lower conf. bounds
    p = ax.collections[0].get_paths()
    p_df = pd.DataFrame(p[0].vertices).sort_values(by=[0, 1]).drop_duplicates()
    constant_bounds = p_df[~p_df[0].duplicated(keep=False)]
    p_df = pd.concat([p_df, constant_bounds]).sort_values(by=0)
    p_df["lim"] = [
        x
        for y in zip(np.tile("lower", len(mean_p_df)), np.tile("upper", len(mean_p_df)))
        for x in y
    ]

    # merge
    p_df_p = p_df.pivot(index=0, columns="lim").reset_index()
    p_df_p.columns = p_df_p.columns.to_flat_index()
    p_df_p = p_df_p.set_axis(["x", "ci_lower", "ci_upper"], axis="columns")
    df = pd.merge(p_df_p, mean_p_df, how="inner", left_on="x", right_on=0)

    df = df.rename(columns={1: "mean"}).drop(0, axis="columns")
    return df[["x", "mean", "ci_lower", "ci_upper"]]

# %%
lgb_auc_ci = _sns_plot_to_df(g.figure.gca())
lgb_auc_ci
# Out:
#         x      mean  ci_lower  ci_upper
# 0     1.0  0.570866  0.553581  0.590963
# 1     6.0  0.661853  0.628581  0.694771
# 2    11.0  0.786532  0.765007  0.810287
# 3    16.0  0.817412  0.796863  0.834797
# 4    21.0  0.869966  0.848196  0.889455
# 5    26.0  0.929379  0.948031  0.910381
# 6    31.0  0.933639  0.920652  0.947185
# 7    36.0  0.961168  0.950005  0.971395
# 8    41.0  0.972949  0.962472  0.982189
# 9    46.0  0.983531  0.977562  0.989266
# 10   51.0  0.987845  0.992256  0.982413
# 11   56.0  0.992470  0.989109  0.995310
# 12   61.0  0.996309  0.993915  0.998028
# 13   66.0  0.996254  0.993799  0.998278
# 14   71.0  0.996294  0.993261  0.998709
# 15   76.0  0.999262  1.000000  0.998095
# 16   81.0  0.997970  0.995387  0.999631
# 17   86.0  0.998633  0.997465  0.999633
# 18   91.0  0.999815  0.999630  1.000000
# 19   96.0  1.000000  1.000000  1.000000
# 20  101.0  0.999754  1.000000  0.999387
# 21  106.0  0.998646  1.000000  0.996498
# 22  111.0  0.999815  0.999568  1.000000
# 23  116.0  0.999753  0.999446  1.000000
# 24  121.0  0.999753  0.999443  1.000000
# 25  126.0  0.999448  0.998710  1.000000
# 26  131.0  0.999939  0.999816  1.000000
# 27  136.0  0.999939  0.999816  1.000000
# 28  141.0  0.999388  1.000000  0.998347
# 29  146.0  1.000000  1.000000  1.000000
# 30  151.0  0.999752  0.999317  1.000000
# 31  156.0  1.000000  1.000000  1.000000
# 32  161.0  1.000000  1.000000  1.000000
# 33  166.0  1.000000  1.000000  1.000000
# 34  171.0  0.999939  1.000000  0.999816
# 35  176.0  0.999938  0.999815  1.000000
# 36  181.0  1.000000  1.000000  1.000000
# 37  186.0  1.000000  1.000000  1.000000
# 38  191.0  1.000000  1.000000  1.000000
# 39  196.0  1.000000  1.000000  1.000000
# 40  201.0  1.000000  1.000000  1.000000
# 41  206.0  1.000000  1.000000  1.000000
# 42  211.0  0.999939  0.999816  1.000000

# %%
lgb_auc_ci.to_csv("lgb_auc_ci.csv", index=False)

# %%
print(tpl.get_tikz_code(fig, standalone=False))
# Out:
# % This file was created with tikzplotlib v0.10.1.
# \begin{tikzpicture}
#
# \definecolor{darkgray176}{RGB}{176,176,176}
# \definecolor{lightgray204}{RGB}{204,204,204}
# \definecolor{steelblue31119180}{RGB}{31,119,180}
#
# \begin{axis}[
# legend cell align={left},
# legend style={
#   fill opacity=0.8,
#   draw opacity=1,
#   text opacity=1,
#   at={(0.03,0.97)},
#   anchor=north west,
#   draw=lightgray204
# },
# tick align=outside,
# tick pos=left,
# x grid style={darkgray176},
# xlabel={questions asked},
# xmin=-9.5, xmax=221.5,
# xtick style={color=black},
# y grid style={darkgray176},
# ymin=0.5266763630605, ymax=1.02346106653809,
# ytick style={color=black}
# ]
# \path [fill=steelblue31119180, fill opacity=0.25]
# (axis cs:1,0.59247494604339)
# --(axis cs:1,0.549257485945845)
# --(axis cs:6,0.625314339370823)
# --(axis cs:11,0.760884978286131)
# --(axis cs:16,0.794851985393529)
# --(axis cs:21,0.846968477998267)
# --(axis cs:26,0.90770791156786)
# --(axis cs:31,0.91858248803595)
# --(axis cs:36,0.948991160867885)
# --(axis cs:41,0.961620232893018)
# --(axis cs:46,0.977098602482914)
# --(axis cs:51,0.982319357683092)
# --(axis cs:56,0.989069665949019)
# --(axis cs:61,0.993973279750547)
# --(axis cs:66,0.993766935301471)
# --(axis cs:71,0.993168717700578)
# --(axis cs:76,0.998168896579911)
# --(axis cs:81,0.995309361680754)
# --(axis cs:86,0.997419511849839)
# --(axis cs:91,0.999603590125892)
# --(axis cs:96,1)
# --(axis cs:101,0.999347613835428)
# --(axis cs:106,0.996412993307837)
# --(axis cs:111,0.999528295403667)
# --(axis cs:116,0.999449424964074)
# --(axis cs:121,0.999448276907346)
# --(axis cs:126,0.998589537494962)
# --(axis cs:131,0.99980730473726)
# --(axis cs:136,0.999807481684241)
# --(axis cs:141,0.998414070168958)
# --(axis cs:146,1)
# --(axis cs:151,0.999339827037289)
# --(axis cs:156,1)
# --(axis cs:161,1)
# --(axis cs:166,1)
# --(axis cs:171,0.999806771939298)
# --(axis cs:176,0.999805877364943)
# --(axis cs:181,1)
# --(axis cs:186,1)
# --(axis cs:191,1)
# --(axis cs:196,1)
# --(axis cs:201,1)
# --(axis cs:206,1)
# --(axis cs:211,0.99980730473726)
# --(axis cs:211,1.00007014624313)
# --(axis cs:211,1.00007014624313)
# --(axis cs:206,1)
# --(axis cs:201,1)
# --(axis cs:196,1)
# --(axis cs:191,1)
# --(axis cs:186,1)
# --(axis cs:181,1)
# --(axis cs:176,1.00007066584493)
# --(axis cs:171,1.00007034019588)
# --(axis cs:166,1)
# --(axis cs:161,1)
# --(axis cs:156,1)
# --(axis cs:151,1.0001639295929)
# --(axis cs:146,1)
# --(axis cs:141,1.00036156497031)
# --(axis cs:136,1.00007008182969)
# --(axis cs:131,1.00007014624313)
# --(axis cs:126,1.00030548825727)
# --(axis cs:121,1.00005677599455)
# --(axis cs:116,1.00005693700346)
# --(axis cs:111,1.00010235453001)
# --(axis cs:106,1.00087994365274)
# --(axis cs:101,1.00016128231563)
# --(axis cs:96,1)
# --(axis cs:91,1.00002704964167)
# --(axis cs:86,0.999846696045181)
# --(axis cs:81,1.00063075563469)
# --(axis cs:76,1.00035537566393)
# --(axis cs:71,0.999419066097009)
# --(axis cs:66,0.998740437372787)
# --(axis cs:61,0.998645370004379)
# --(axis cs:56,0.995870118177725)
# --(axis cs:51,0.993371303085309)
# --(axis cs:46,0.989963165845949)
# --(axis cs:41,0.984277913678666)
# --(axis cs:36,0.97334487895347)
# --(axis cs:31,0.948694618387925)
# --(axis cs:26,0.951049218603779)
# --(axis cs:21,0.892962581723163)
# --(axis cs:16,0.839972789862799)
# --(axis cs:11,0.812178335601879)
# --(axis cs:6,0.698392017070825)
# --(axis cs:1,0.59247494604339)
# --cycle;
#
# \addplot [semithick, steelblue31119180]
# table {%
# 1 0.570866215994617
# 6 0.661853178220824
# 11 0.786531656944005
# 16 0.817412387628164
# 21 0.869965529860715
# 26 0.92937856508582
# 31 0.933638553211937
# 36 0.961168019910677
# 41 0.972949073285842
# 46 0.983530884164432
# 51 0.9878453303842
# 56 0.992469892063372
# 61 0.996309324877463
# 66 0.996253686337129
# 71 0.996293891898794
# 76 0.999262136121923
# 81 0.997970058657723
# 86 0.99863310394751
# 91 0.999815319883778
# 96 1
# 101 0.999754448075526
# 106 0.998646468480291
# 111 0.99981532496684
# 116 0.999753180983769
# 121 0.99975252645095
# 126 0.999447512876118
# 131 0.999938725490196
# 136 0.999938781756964
# 141 0.999387817569636
# 146 1
# 151 0.999751878315097
# 156 1
# 161 1
# 166 1
# 171 0.999938556067588
# 176 0.999938271604938
# 181 1
# 186 1
# 191 1
# 196 1
# 201 1
# 206 1
# 211 0.999938725490196
# };
# \addlegendentry{mean}
# \end{axis}
#
# \end{tikzpicture}

# %%
df = lgb_auc_ci

# %%
x = pd.Series([x for x in np.arange(1, 212, 0.5) if x not in df["x"].values], name="x")

# %%
x
# Out:
# 0        1.5
# 1        2.0
# 2        2.5
# 3        3.0
# 4        3.5
#        ...
# 374    209.0
# 375    209.5
# 376    210.0
# 377    210.5
# 378    211.5
# Name: x, Length: 379, dtype: float64

# %%
pd.concat([df, pd.DataFrame(x)]).sort_values(by="x").reset_index(drop=True)
# Out:
#          x      mean  ci_lower  ci_upper
# 0      1.0  0.553178  0.530816   0.57898
# 1      1.5       NaN       NaN       NaN
# 2      2.0       NaN       NaN       NaN
# 3      2.5       NaN       NaN       NaN
# 4      3.0       NaN       NaN       NaN
# ..     ...       ...       ...       ...
# 417  209.5       NaN       NaN       NaN
# 418  210.0       NaN       NaN       NaN
# 419  210.5       NaN       NaN       NaN
# 420  211.0  1.000000  1.000000   1.00000
# 421  211.5       NaN       NaN       NaN
#
# [422 rows x 4 columns]

# %%
g.figure

# %%
ddf = (
    pd.concat([df, pd.DataFrame(x)])
    .sort_values(by="x")
    .reset_index(drop=True)
    .interpolate(method="pchip")
)

ax = ddf.plot(x="x", y="mean")
ax.fill_between(ddf["x"], ddf["ci_lower"], ddf["ci_upper"], alpha=0.25)

# %%
ddf.head(20)
# Out:
#        x      mean  ci_lower  ci_upper
# 0    1.0  0.553178  0.530816  0.578980
# 1    1.5  0.555084  0.527392  0.584959
# 2    2.0  0.558954  0.527088  0.591962
# 3    2.5  0.564614  0.529632  0.599899
# 4    3.0  0.571892  0.534753  0.608680
# 5    3.5  0.580617  0.542180  0.618214
# 6    4.0  0.590617  0.551641  0.628410
# 7    4.5  0.601719  0.562865  0.639179
# 8    5.0  0.613751  0.575581  0.650429
# 9    5.5  0.626541  0.589517  0.662070
# 10   6.0  0.639918  0.604401  0.674011
# 11   6.5  0.653708  0.619963  0.686163
# 12   7.0  0.667739  0.635931  0.698434
# 13   7.5  0.681841  0.652034  0.710733
# 14   8.0  0.695840  0.668000  0.722971
# 15   8.5  0.709564  0.683558  0.735057
# 16   9.0  0.722841  0.698436  0.746900
# 17   9.5  0.735500  0.712364  0.758410
# 18  10.0  0.747367  0.725070  0.769496
# 19  10.5  0.758271  0.736283  0.780067

# %%
from scipy.interpolate import BSpline, interp1d, make_interp_spline


def _get_spline_dat(df, x, var):
    cubic = make_interp_spline(df[x], df[var], k=1)
    res = cubic(np.linspace(df[x].min(), df[x].max(), num=50, endpoint=True))

    return res


def _get_all_splines(dat, x):
    df = pd.DataFrame(dat).reset_index()
    resdf = pd.DataFrame(
        [_get_spline_dat(df, x, var) for var in df.columns]
    ).transpose()
    resdf.columns = df.columns

    return pd.melt(resdf, id_vars=x)

# %%
_get_all_splines(df, "x")
# Out:
#               x  variable     value
# 0      1.000000     index  0.000000
# 1      5.285714     index  0.857143
# 2      9.571429     index  1.714286
# 3     13.857143     index  2.571429
# 4     18.142857     index  3.428571
# ..          ...       ...       ...
# 195  193.857143  ci_upper  1.000000
# 196  198.142857  ci_upper  1.000000
# 197  202.428571  ci_upper  1.000000
# 198  206.714286  ci_upper  1.000000
# 199  211.000000  ci_upper  1.000000
#
# [200 rows x 3 columns]

# %%
sns.relplot(
    data=_get_all_splines(df, "x").query("variable!='index'"),
    x="x",
    y="value",
    hue="variable",
    kind="line",
)

# %%
lgb
# Out:
#     questions asked       auc     z_auc  z_auc_lb  z_auc_ub
# 0                 1  0.590909  0.590909  0.590909  0.590909
# 1                 6  0.613889  0.643056  0.561552  0.724664
# 2                11  0.735294  0.771000  0.706181  0.835864
# 3                16  0.769585  0.795714  0.739375  0.852109
# 4                21  0.810150  0.833632  0.780535  0.886750
# ..              ...       ...       ...       ...       ...
# 38              191  1.000000  0.500000  0.417720  0.582588
# 39              196  1.000000  0.500000  0.417720  0.582588
# 40              201  1.000000  0.500000  0.417720  0.582588
# 41              206  1.000000  0.500000  0.417720  0.582588
# 42              211  1.000000  0.500000  0.417720  0.582588
#
# [344 rows x 5 columns]
